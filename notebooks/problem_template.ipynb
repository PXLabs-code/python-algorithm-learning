# %% [markdown]
# # 题目名称
#
# > 复制此 Notebook 后，将文件名和下方 Colab 链接中的路径改为新题名称。
#
# [![在 Google Colab 中打开](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PXLabs-code/python-algorithm-learning/blob/main/notebooks/problem_template.ipynb)
#
# ## 题目
#
# 在这里填写题目描述、输入输出约束和示例。

# %% [markdown]
# ## 思路
#
# 在这里记录解题思路，并分析时间复杂度与空间复杂度。

# %%
def solve():
    """在这里实现解法。"""
    pass

# %% [markdown]
# ## 正确性断言与边界测试
#
# 至少覆盖普通输入、最小规模、重复值、空输入或无解情况（按题目约束取舍）。

# %%
# assert solve(...) == ...

# %% [markdown]
# ## `timeit` 效率测试
#
# 准备具有代表性的输入，重复运行并记录结果。

# %%
from timeit import repeat

# runs = repeat(lambda: solve(...), number=100, repeat=5)
# print(f"每次调用最佳耗时：{min(runs) / 100 * 1_000:.3f} ms")
